# %% [markdown]
# # Tâche 6

# %% [markdown]
# --> pour déterminer les 3 premiers pics du diffractogramme correspondant (en indiquant les indices hkl associés) pour un rayonnement X incident Cu Kα de longueur d’onde λ=1.54060 Å

# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifWriter
from IPython.display import FileLink
from pymatgen.analysis.diffraction.xrd import XRDCalculator
import matplotlib.pyplot as plt

# %%
key =  "rEVEIFsc61iExKZbJ2QyepniwSgJ1m6W"  #my key for API access
material = "mp-28554"    #ID of my material
m = MPRester(key)
struct = m.get_structure_by_material_id(material,conventional_unit_cell=True) #Getting structure object
w = CifWriter(struct)    #Write to CIF
w.write_file(material+".cif") 
display(FileLink(material+".cif"))
# Out:
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/users/m/w/mwillems/mp-28554.cif

# %%
#objet XRDCalculator
xrd = XRDCalculator(1.54060)
#Calcul de la diffraction
dif = xrd.get_pattern(struct)
xrd.get_plot(struct, annotate_peaks=False, two_theta_range=[0, 180])
plt.show()
for i in range(3):
    print("Pic numéro "+str(i+1))
    print("Angle du pic : "+str(dif.x[i]))
    print("Intensité du pic : "+str(dif.y[i]))
    print("Indices hkl du pic : "+str(dif.hkls[i][0]["hkl"]))
    print("Multiplicité du pic : "+str(dif.hkls[i][0]["multiplicity"]))
    print(" ")
# Out:
# Pic numéro 1
# Angle du pic : 11.868168184888228
# Intensité du pic : 0.8585625125084501
# Indices hkl du pic : (0, 0, 0, 3)
# Multiplicité du pic : 2
#
# Pic numéro 2
# Angle du pic : 23.68549737337363
# Intensité du pic : 6.760949854806205
# Indices hkl du pic : (1, 0, -1, 1)
# Multiplicité du pic : 12
#
# Pic numéro 3
# Angle du pic : 23.86608926456542
# Intensité du pic : 12.35866831841126
# Indices hkl du pic : (0, 0, 0, 6)
# Multiplicité du pic : 2
